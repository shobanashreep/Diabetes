# %%
# =========================================================
# Building Artificial Neural Network (ANN)
# Diabetes Prediction using TensorFlow and Keras
# =========================================================

# Import Libraries
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778922038.198172   55021 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1778922038.200475   55021 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1778922038.622675   55021 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778922040.971741   55021 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1778922040.974023   55021 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# =========================================================
# 1. Data Loading
# =========================================================

# Load Dataset
dataset = pd.read_csv("diabetes.csv")

# Display first 5 rows
print(dataset.head())
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
# =========================================================
# 2. Data Preprocessing
# =========================================================

# Separate input and output variables
X = dataset.iloc[:, 0:8].values
y = dataset.iloc[:, 8].values

# Feature Scaling
sc = StandardScaler()
X = sc.fit_transform(X)

# Split dataset into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=0
)

# %%
# =========================================================
# 3. Model Architecture
# =========================================================

# Create ANN model
model = tf.keras.models.Sequential()

# First Hidden Layer
model.add(tf.keras.layers.Dense(
    units=12,
    activation='relu',
    input_shape=(8,)
))

# Second Hidden Layer
model.add(tf.keras.layers.Dense(
    units=8,
    activation='relu'
))

# Output Layer
model.add(tf.keras.layers.Dense(
    units=1,
    activation='sigmoid'
))

# Display Model Summary
model.summary()
# Out:
# /home/intellact/tfenv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1778922042.930951   55021 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 12)             │           108 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221 (884.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# =========================================================
# 4. Compilation
# =========================================================

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# =========================================================
# 5. Training
# =========================================================

history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4347 - loss: 0.7350 - val_accuracy: 0.4390 - val_loss: 0.7308
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5204 - loss: 0.7048 - val_accuracy: 0.4878 - val_loss: 0.7132
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6000 - loss: 0.6799 - val_accuracy: 0.5528 - val_loss: 0.6979
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6571 - loss: 0.6576 - val_accuracy: 0.5772 - val_loss: 0.6851
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6980 - loss: 0.6367 - val_accuracy: 0.5935 - val_loss: 0.6737
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7061 - loss: 0.6164 - val_accuracy: 0.5935 - val_loss: 0.6628
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7265 - loss: 0.5971 - val_accuracy: 0.6016 - val_loss: 0.6531
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7286 - loss: 0.5794 - val_accuracy: 0.6179 - val_loss: 0.6452
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7327 - loss: 0.5638 - val_accuracy: 0.6341 - val_loss: 0.6377
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7408 - loss: 0.5502 - val_accuracy: 0.6504 - val_loss: 0.6311
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7388 - loss: 0.5370 - val_accuracy: 0.6504 - val_loss: 0.6247
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7429 - loss: 0.5241 - val_accuracy: 0.6667 - val_loss: 0.6182
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7469 - loss: 0.5125 - val_accuracy: 0.6585 - val_loss: 0.6132
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7531 - loss: 0.5035 - val_accuracy: 0.6504 - val_loss: 0.6087
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7612 - loss: 0.4943 - val_accuracy: 0.6585 - val_loss: 0.6045
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7735 - loss: 0.4866 - val_accuracy: 0.6667 - val_loss: 0.5997
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7776 - loss: 0.4793 - val_accuracy: 0.6748 - val_loss: 0.5975
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7796 - loss: 0.4740 - val_accuracy: 0.6748 - val_loss: 0.5935
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7776 - loss: 0.4675 - val_accuracy: 0.6829 - val_loss: 0.5908
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7816 - loss: 0.4623 - val_accuracy: 0.6992 - val_loss: 0.5882
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7878 - loss: 0.4579 - val_accuracy: 0.6911 - val_loss: 0.5859
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7878 - loss: 0.4528 - val_accuracy: 0.6748 - val_loss: 0.5827
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7837 - loss: 0.4491 - val_accuracy: 0.6911 - val_loss: 0.5807
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7878 - loss: 0.4452 - val_accuracy: 0.6829 - val_loss: 0.5796
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7878 - loss: 0.4422 - val_accuracy: 0.6911 - val_loss: 0.5793
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7898 - loss: 0.4395 - val_accuracy: 0.6829 - val_loss: 0.5779
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7837 - loss: 0.4371 - val_accuracy: 0.6829 - val_loss: 0.5793
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7878 - loss: 0.4348 - val_accuracy: 0.6911 - val_loss: 0.5776
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7898 - loss: 0.4329 - val_accuracy: 0.6911 - val_loss: 0.5777
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7918 - loss: 0.4310 - val_accuracy: 0.6992 - val_loss: 0.5781
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7898 - loss: 0.4297 - val_accuracy: 0.6911 - val_loss: 0.5783
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7939 - loss: 0.4275 - val_accuracy: 0.6911 - val_loss: 0.5793
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7959 - loss: 0.4264 - val_accuracy: 0.6911 - val_loss: 0.5813
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7959 - loss: 0.4250 - val_accuracy: 0.6748 - val_loss: 0.5816
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7939 - loss: 0.4240 - val_accuracy: 0.6748 - val_loss: 0.5830
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7959 - loss: 0.4229 - val_accuracy: 0.6748 - val_loss: 0.5825
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7980 - loss: 0.4218 - val_accuracy: 0.6748 - val_loss: 0.5812
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7959 - loss: 0.4212 - val_accuracy: 0.6748 - val_loss: 0.5826
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7939 - loss: 0.4203 - val_accuracy: 0.6748 - val_loss: 0.5835
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7980 - loss: 0.4191 - val_accuracy: 0.6748 - val_loss: 0.5844
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7939 - loss: 0.4186 - val_accuracy: 0.6748 - val_loss: 0.5838
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - loss: 0.4176 - val_accuracy: 0.6748 - val_loss: 0.5856
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8000 - loss: 0.4167 - val_accuracy: 0.6748 - val_loss: 0.5878
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8000 - loss: 0.4157 - val_accuracy: 0.6748 - val_loss: 0.5882
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8000 - loss: 0.4157 - val_accuracy: 0.6748 - val_loss: 0.5883
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7980 - loss: 0.4144 - val_accuracy: 0.6748 - val_loss: 0.5899
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8000 - loss: 0.4137 - val_accuracy: 0.6748 - val_loss: 0.5906
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8020 - loss: 0.4128 - val_accuracy: 0.6748 - val_loss: 0.5914
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8020 - loss: 0.4124 - val_accuracy: 0.6748 - val_loss: 0.5925
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8000 - loss: 0.4111 - val_accuracy: 0.6829 - val_loss: 0.5928

# %%
# =========================================================
# 6. Evaluation
# =========================================================

loss, accuracy = model.evaluate(X_test, y_test)

print("\nModel Evaluation")
print("Loss :", loss)
print("Accuracy :", accuracy)

# =========================================================
# Prediction
# =========================================================

predictions = model.predict(X_test)

print("\nSample Predictions")
print(predictions[:5])
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7792 - loss: 0.4478
#
# Model Evaluation
# Loss : 0.44781211018562317
# Accuracy : 0.7792207598686218
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Sample Predictions
# [[0.79038996]
#  [0.2466054 ]
#  [0.798016  ]
#  [0.2143742 ]
#  [0.22448306]]

# %%
model.save("diabetes_model.keras")

print("Model Saved")
# Out:
# Model Saved

# %% [markdown]
# # Building Your First Artificial Neural Network (ANN)
#
# This project demonstrates how to build a basic ANN using TensorFlow and Keras to predict diabetes based on diagnostic measurements. We will use the **Pima Indians Diabetes Dataset**.
#
# ## Project Overview
# 1. **Data Loading**: Load the CSV dataset.
# 2. **Data Preprocessing**: Prepare the data for the neural network.
# 3. **Model Architecture**: Define the ANN using the Sequential API.
# 4. **Compilation**: Configure the learning process.
# 5. **Training**: Train the model on the data.
# 6. **Evaluation**: Assess the model's performance.

# %%
# =========================================================
# Building Artificial Neural Network (ANN)
# Diabetes Prediction using TensorFlow and Keras
# =========================================================

# Import Libraries
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/intellact/tfenv/lib/python3.11/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/intellact/tfenv/lib/python3.11/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/intellact/tfenv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/intellact/tfenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/intellact/.local/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/intellact/.local/lib/python3.8/site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in /home/intellact/.local/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/intellact/.local/lib/python3.8/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/intellact/.local/lib/python3.8/site-packages (from scikit-learn) (3.5.0)

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/intellact/tfenv/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/intellact/tfenv/lib/python3.11/site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in /home/intellact/tfenv/lib/python3.11/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/intellact/tfenv/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/intellact/tfenv/lib/python3.11/site-packages (from scikit-learn) (3.6.0)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0

# %% [markdown]
# ## 1. Data Loading
# The dataset contains 8 medical predictor variables and one target variable (Outcome).

# %%
# =========================================================
# 1. Data Loading
# =========================================================

# Load Dataset
dataset = pd.read_csv("diabetes.csv")

# Display first 5 rows
print(dataset.head())
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %% [markdown]
# ## 2. Data Preprocessing
# Neural networks perform best when input features are on a similar scale.

# %%
# =========================================================
# 2. Data Preprocessing
# =========================================================

# Separate input and output variables
X = dataset.iloc[:, 0:8].values
y = dataset.iloc[:, 8].values

# Feature Scaling
sc = StandardScaler()
X = sc.fit_transform(X)

# Split dataset into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=0
)

# %% [markdown]
# ## 3. Model Architecture
# We will use the `Sequential` API to stack layers.
# - **Input Layer**: 8 features.
# - **Hidden Layers**: Dense layers with ReLU activation(3 hidden layers with 12,8,1 consist of relu, relu and output layer sigmoid).
# - **Output Layer**: 1 neuron with Sigmoid activation (for binary classification).

# %%
# =========================================================
# 3. Model Architecture
# =========================================================

# Create ANN model
model = tf.keras.models.Sequential()

# First Hidden Layer
model.add(tf.keras.layers.Dense(
    units=12,
    activation='relu',
    input_shape=(8,)
))

# Second Hidden Layer
model.add(tf.keras.layers.Dense(
    units=8,
    activation='relu'
))

# Output Layer
model.add(tf.keras.layers.Dense(
    units=1,
    activation='sigmoid'
))

# Display Model Summary
model.summary()
# Out:
# /home/intellact/tfenv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1778746833.599569    6914 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 12)             │           108 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221 (884.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 4. Compilation
# We use `binary_crossentropy` for loss and `adam` as the optimizer.

# %%
# =========================================================
# 4. Compilation
# =========================================================

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## 5. Training
# We train the model for 100 epochs.

# %%
# =========================================================
# 5. Training
# =========================================================

history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6571 - loss: 0.6536 - val_accuracy: 0.6341 - val_loss: 0.6602
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7204 - loss: 0.6213 - val_accuracy: 0.6748 - val_loss: 0.6423
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7531 - loss: 0.5930 - val_accuracy: 0.6667 - val_loss: 0.6263
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7633 - loss: 0.5684 - val_accuracy: 0.6992 - val_loss: 0.6123
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7673 - loss: 0.5464 - val_accuracy: 0.6667 - val_loss: 0.6015
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7796 - loss: 0.5280 - val_accuracy: 0.7073 - val_loss: 0.5936
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.5135 - val_accuracy: 0.6829 - val_loss: 0.5881
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7959 - loss: 0.5004 - val_accuracy: 0.6748 - val_loss: 0.5846
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7959 - loss: 0.4887 - val_accuracy: 0.6667 - val_loss: 0.5819
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7980 - loss: 0.4793 - val_accuracy: 0.6667 - val_loss: 0.5807
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7959 - loss: 0.4715 - val_accuracy: 0.6667 - val_loss: 0.5811
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7959 - loss: 0.4641 - val_accuracy: 0.6667 - val_loss: 0.5816
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4583 - val_accuracy: 0.6667 - val_loss: 0.5826
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8000 - loss: 0.4533 - val_accuracy: 0.6667 - val_loss: 0.5841
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7959 - loss: 0.4484 - val_accuracy: 0.6748 - val_loss: 0.5855
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7959 - loss: 0.4448 - val_accuracy: 0.6829 - val_loss: 0.5872
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7959 - loss: 0.4413 - val_accuracy: 0.6748 - val_loss: 0.5888
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.4385 - val_accuracy: 0.6829 - val_loss: 0.5913
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7918 - loss: 0.4358 - val_accuracy: 0.6748 - val_loss: 0.5929
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.4336 - val_accuracy: 0.6748 - val_loss: 0.5938
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4321 - val_accuracy: 0.6829 - val_loss: 0.5967
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7939 - loss: 0.4307 - val_accuracy: 0.6829 - val_loss: 0.5980
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4292 - val_accuracy: 0.6748 - val_loss: 0.5993
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7980 - loss: 0.4271 - val_accuracy: 0.6829 - val_loss: 0.5996
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4258 - val_accuracy: 0.6748 - val_loss: 0.5996
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7959 - loss: 0.4248 - val_accuracy: 0.6748 - val_loss: 0.6017
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8000 - loss: 0.4240 - val_accuracy: 0.6829 - val_loss: 0.6024
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.4223 - val_accuracy: 0.6748 - val_loss: 0.6038
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4211 - val_accuracy: 0.6667 - val_loss: 0.6056
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.4204 - val_accuracy: 0.6667 - val_loss: 0.6065
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4193 - val_accuracy: 0.6585 - val_loss: 0.6078
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8020 - loss: 0.4186 - val_accuracy: 0.6585 - val_loss: 0.6091
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8041 - loss: 0.4184 - val_accuracy: 0.6585 - val_loss: 0.6088
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4171 - val_accuracy: 0.6585 - val_loss: 0.6120
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.4164 - val_accuracy: 0.6585 - val_loss: 0.6113
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4152 - val_accuracy: 0.6585 - val_loss: 0.6130
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.4146 - val_accuracy: 0.6748 - val_loss: 0.6150
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4148 - val_accuracy: 0.6585 - val_loss: 0.6148
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4132 - val_accuracy: 0.6585 - val_loss: 0.6158
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4123 - val_accuracy: 0.6667 - val_loss: 0.6174
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.4119 - val_accuracy: 0.6748 - val_loss: 0.6192
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.4124 - val_accuracy: 0.6667 - val_loss: 0.6248
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.4102 - val_accuracy: 0.6748 - val_loss: 0.6245
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4102 - val_accuracy: 0.6667 - val_loss: 0.6219
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4090 - val_accuracy: 0.6667 - val_loss: 0.6245
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - loss: 0.4091 - val_accuracy: 0.6667 - val_loss: 0.6271
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8041 - loss: 0.4085 - val_accuracy: 0.6748 - val_loss: 0.6260
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8061 - loss: 0.4074 - val_accuracy: 0.6748 - val_loss: 0.6273
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8041 - loss: 0.4072 - val_accuracy: 0.6748 - val_loss: 0.6279
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4064 - val_accuracy: 0.6667 - val_loss: 0.6281

# %% [markdown]
# ## 6. Evaluation
# Check how the model performs on unseen data.

# %%
# =========================================================
# 6. Evaluation
# =========================================================

loss, accuracy = model.evaluate(X_test, y_test)

print("\nModel Evaluation")
print("Loss :", loss)
print("Accuracy :", accuracy)

# =========================================================
# Prediction
# =========================================================

predictions = model.predict(X_test)

print("\nSample Predictions")
print(predictions[:5])
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7792 - loss: 0.4687
#
# Model Evaluation
# Loss : 0.4686836004257202
# Accuracy : 0.7792207598686218
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Sample Predictions
# [[0.457242  ]
#  [0.25427696]
#  [0.7186767 ]
#  [0.3385184 ]
#  [0.15880279]]
